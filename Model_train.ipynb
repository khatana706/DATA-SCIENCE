# %% [markdown]
# <a href="https://colab.research.google.com/github/khatana706/DATA-SCIENCE/blob/train/Model_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Check the gpu
# 1.  for tiny_model, tiny_plus_model only T4 and K80 are allowed.
# 2.  for big_model only P100, T4 and K80 are allowed.

# %%
from IPython.display import HTML, clear_output
from subprocess import getoutput
s = getoutput('nvidia-smi')
if 'K80' in s:gpu = 'K80'
elif 'T4' in s:gpu = 'T4'
elif 'P100' in s:gpu = 'P100'
else:gpu='DONT PROCEED'
display(HTML(f"<h1>{gpu}</h1>"))
# Out:
# <h1>P100</h1>

# %% [markdown]
# # Mount the drive and import necessary libraries

# %%
from google.colab import drive
from os import listdir, remove, makedirs
from os.path import join, exists
import random
drive.mount('/gdrive')
# %cd /gdrive/MyDrive/darknet
# !chmod +x ./darknet
# !./darknet
# Out:
# Mounted at /gdrive
# /gdrive/MyDrive/darknet
# usage: ./darknet <function>

# %% [markdown]
# # Start Training from beginning
# 1.  No need to run below this, if you are going to **resume**. [Click here](#resume-cell) to go to the resume cell.

# %%
# change this path
inputpath="topwear_new"
if "gdrive" not in inputpath:
    inputpath = "/gdrive/MyDrive/"+inputpath
if exists(inputpath):
    x = input("Which model you want to train?\n\t1. tiny model\n\t2. tiny plus model\n\t3. big model\n")
    dont_run=False
    if x=='1':model_type = "tiny_model"
    elif x=='2':model_type = "tiny_plus_model"
    elif x=='3':model_type = "big_model"
    else:
        dont_run=True
        clear_output()
        print("Enter correct input among 1,2 and 3.")
else:
    print(inputpath, "cannot be found please correct it.")
# Out:
# Which model you want to train?
# 	1. tiny model
# 	2. tiny plus model
# 	3. big model
# 3

# %% [markdown]
# ### Helper Functions

# %%
def check_existence(folder, count=0):
    tmp="" if count==0 else "_"+str(count)
    check_folder = folder+tmp
    if (check_folder in listdir(".")) and (len([k for k in listdir(check_folder) if ".weights" in k])!=0):
        count+=1
        return check_existence(folder, count)
    else:
        return check_folder
def get_all_files(folder:str, result:dict):
    tmp = sorted(listdir(folder))
    result[folder]=[i for i in tmp if (".jpg" in i) or (".txt" in i)]
    for i in tmp:
        if "." not in i:
            get_all_files(join(folder, i), result)
def get_images_txt(folder:str):
    data = {}
    get_all_files(folder, data)
    del data[folder]
    final_data = {}
    for i in data.keys():
        if len(data[i])==0:
            continue
        class_ = i[len(folder)+1:].split("/")[0]
        if class_ not in final_data.keys():
            final_data[class_]={}
        final_data[class_][i] = []
        for j in range(len(data[i])-1):
            if data[i][j][:data[i][j].rfind('.')]==data[i][j+1][:data[i][j+1].rfind('.')]:
                final_data[class_][i].append([i+'/'+data[i][j], i+'/'+data[i][j+1]])
                j+=1
    return final_data

# %% [markdown]
# ### Confirm the output folder

# %%
if not dont_run:
    clear_output()
    outputpath="_".join(inputpath.split("/")[3:])+"_"+model_type
    outputpath = check_existence(outputpath)
    print("Output folder is "+outputpath+".")
    x = input("Please confirm to create the output folder (y/n):")
    if x == 'y':
        if not exists(outputpath):
            makedirs(outputpath)
        print("Output folder created.")
    elif x == 'n':
        print("Output folder not created.")
    else:
        print("Please input valid character.")
# Out:
# Output folder is topwear_new_big_model.
# Please confirm to create the output folder (y/n):y
# Output folder created.

# %% [markdown]
# ### Confirm the count of images and classes.
# 1.  Those numbers tells the count of pair of image and it's annotation.
# 2.  Adjust the threshold value to increase and decrease the classes.

# %%
threshold = 10
data = get_images_txt(inputpath)
key_list = sorted(list(data.keys()))
count=0
for i in key_list:
    l = sum([len(k) for k in data[i].values()])
    if l>threshold:
        print(count,i, l)
        count+=1
    else:
        del data[i]
x = input("Please confirm that classes and count of images are correct (y/n):")
if x == 'y':
    classes = sorted(data.keys())
    print("Classes selected.")
elif x == 'n':
    classes = None
    print("Classes not selected.")
else:
    classes = None
    print("Please input valid character.")
# Out:
# 0 brassiere 692
# 1 shirts 2182
# 2 sweatshirt 1137
# 3 tops 5851
# Please confirm that classes and count of images are correct (y/n):y
# Classes selected.

# %%
def clip_first(n, d):
    key_list = sorted(list(d.keys()))
    result = {i:[] for i in key_list}
    key_counter = {i:0 for i in key_list}
    prev = 0
    while True:
        for i in key_list:
            if key_counter[i]>=len(d[i]):
                continue
            else:
                result[i].append(d[i][key_counter[i]])
                key_counter[i]+=1
        x = sum([len(k) for k in result.values()])
        if x==prev:
            break
        prev = x
        if sum([len(k) for k in result.values()])>=n:
            break
    return result

# %%
key_list = sorted(list(data.keys()))
min_count=100000000
for i in key_list:
    l = sum([len(k) for k in data[i].values()])
    min_count = min(min_count, l)
print("Minimum number of images in a class:",min_count)
for i in key_list:
    data[i] = clip_first(min_count, data[i])
count = 0
for i in key_list:
    l = sum([len(k) for k in data[i].values()])
    print(count, i, l)
    count+=1
x = input("Please confirm that clipped count of images are correct (y/n):")
if x == 'y':
    classes = sorted(data.keys())
    print("Classes selected.")
elif x == 'n':
    classes = None
    print("Classes not selected.")
else:
    classes = None
    print("Please input valid character.")
# Out:
# Minimum number of images in a class: 692
# 0 brassiere 692
# 1 shirts 692
# 2 sweatshirt 692
# 3 tops 692
# Please confirm that clipped count of images are correct (y/n):y
# Classes selected.

# %%
for i in classes:
    print(i)
    for j in sorted(data[i].keys()):
        print(j, len(data[i][j]))
    print()
# Out:
# brassiere
# /gdrive/MyDrive/topwear_new/brassiere 692
#
# shirts
# /gdrive/MyDrive/topwear_new/shirts 692
#
# sweatshirt
# /gdrive/MyDrive/topwear_new/sweatshirt 692
#
# tops
# /gdrive/MyDrive/topwear_new/tops 692

# %% [markdown]
# ### Change ids in the annotation files
# 1.  This cell will take some time.

# %%
for id in range(len(classes)):
    tmp = 0
    cls = classes[id]
    print(cls+"-", end = " ")
    for i in data[cls].keys():
        for j in data[cls][i]:
            f = open(j[1],'r')
            s = [k.split(" ") for k in f.read().split('\n')]
            s = [k for k in s if len(k)==5]
            s = [[str(id)]+k[1:] for k in s]
            s = "\n".join([" ".join(k) for k in s])+"\n"
            f.close()
            f = open(j[1],'w')
            f.write(s)
            f.close()
            tmp+=1
            if tmp%100==0:
                print(tmp, end=".. ")
    print(tmp)
# Out:
# brassiere- 100.. 200.. 300.. 400.. 500.. 600..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-9203279af3e9> in <module>()
#       6         for j in data[cls][i]:
#       7             f = open(j[1],'r')
# ----> 8             s = [k.split(" ") for k in f.read().split('\n')]
#       9             s = [k for k in s if len(k)==5]
#      10             s = [[str(id)]+k[1:] for k in s]
#
# /usr/lib/python3.7/codecs.py in decode(self, input, final)
#     317         raise NotImplementedError
#     318
# --> 319     def decode(self, input, final=False):
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
#
# KeyboardInterrupt:

# %% [markdown]
# ### Save the training data

# %%
train=[]
for id in range(len(classes)):
    for i in data[classes[id]].keys():
        train.extend([k[0] for k in data[classes[id]][i]])
train=[i for i in train if ".txt" not in i]
random.shuffle(train)
l=len(train)
valid=train[int(l*5/6):]
train=train[:int(l*5/6)]
f=open(join(outputpath, model_type+"_train.txt"),'w')
f.write("\n".join(train))
f.close()
f=open(join(outputpath, model_type+"_valid.txt"),'w')
f.write("\n".join(valid))
f.close()

# %% [markdown]
# ### Save the names file and data file

# %%
f=open(join(outputpath, model_type+"_obj.names"),'w')
f.write("\n".join(classes))
f.close()
numClass=len(classes)
objdata=["classes= "+str(numClass),
         "train = "+join(outputpath, model_type+"_train.txt"),
         "valid = "+join(outputpath, model_type+"_valid.txt"),
         "names = "+join(outputpath, model_type+"_obj.names"),
         "backup = "+outputpath+"/"]
f=open(join(outputpath, model_type+"_obj.data"),"w")
f.write("\n".join(objdata))
f.close()

# %% [markdown]
# ### Copy the appropriate config file

# %%
import shutil
dest_cfg_name = model_type+"_yolov4.cfg"
if model_type == "tiny_model":
    src_cfg_name = "yolov4-tiny-custom.cfg"
    netSize=416
    batch=64
    subdiv=1
    max_batches_multiplier = 3000
    default_max_batch = 500200
elif model_type == "tiny_plus_model":
    src_cfg_name = "yolov4-tiny-custom.cfg"
    netSize=608
    batch=64
    subdiv=2
    max_batches_multiplier = 3000
    default_max_batch = 500200
elif model_type == "big_model":
    src_cfg_name = "yolov4-custom.cfg"
    netSize=416
    batch=64
    subdiv=16
    max_batches_multiplier = 2000
    default_max_batch = 500500
if dest_cfg_name not in listdir(outputpath):
    shutil.copy("cfg/"+src_cfg_name, outputpath+'/'+dest_cfg_name)
else:
    remove(outputpath+'/'+dest_cfg_name)
    shutil.copy("cfg/"+src_cfg_name, outputpath+'/'+dest_cfg_name)

# %% [markdown]
# ### Configure the training details

# %%
#change number of class and filters
comm='s/classes=80/classes='+str(numClass)+"/"
# !sed -i $comm $outputpath/$dest_cfg_name
comm='s/filters=255/filters='+str((numClass+5)*3)+"/"
# !sed -i $comm $outputpath/$dest_cfg_name

#change number of steps and max batches
max_batches=max(6000,(numClass)*max_batches_multiplier)
comm='s/max_batches\ =\ '+str(default_max_batch)+'/max_batches\ =\ '+str(max_batches)+"/"
# !sed -i $comm $outputpath/$dest_cfg_name
comm='s/steps=400000,450000/steps='+str(int(0.8*max_batches))+','+str(int(0.9*max_batches))+"/"
# !sed -i $comm $outputpath/$dest_cfg_name

#can be multiple of 32 or 608(but makes training slow)
comm='s/width=416/width='+str(netSize)+"/"
# !sed -i $comm $outputpath/$dest_cfg_name
comm='s/height=416/height='+str(netSize)+"/"
# !sed -i $comm $outputpath/$dest_cfg_name

comm='s/batch=64/batch='+str(batch)+'/'
# !sed -i $comm $outputpath/$dest_cfg_name
comm='s/subdivisions=1/subdivisions='+str(subdiv)+'/'
# !sed -i $comm $outputpath/$dest_cfg_name

# %% [markdown]
# ### Download the weight if doesn't exist

# %%
if "yolov4.conv.137" not in listdir():
    # !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137
if "yolov4-tiny.conv.29" not in listdir():
    # !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.conv.29

# %% [markdown]
# # Start the training
# 1.  if you are running from the top, then run the below cell directly.
# 2.  if you have done the configurations before hand, and want to run this cell, then define the outputpath variable in some other cell, and then run the below cell.
# 3.  outputpath variable contains the folder name in which model will be saved.

# %%
obj_file = None
cfg_file = None

if "tiny_model" in outputpath : model_name = "yolov4-tiny.conv.29"
elif "tiny_plus_model" in outputpath : model_name = "yolov4-tiny.conv.29"
elif "big_model" in outputpath : model_name = "yolov4.conv.137"

for i in listdir(outputpath):
    if "obj.data" in i:
        obj_file = join(outputpath, i)
    elif ".cfg" in i:
        cfg_file = join(outputpath, i)

if obj_file == None:
    print(".data file not found in", outputpath)

if cfg_file ==None:
    print(".cfg file not found in", outputpath)

if (obj_file != None) and (cfg_file != None):
    # !./darknet detector train $obj_file $cfg_file $model_name -dont_show -map

# %% [markdown]
# <a name="resume-cell"></a>
# # Resume the training
# 1. For resuming the training process, it is complulsory to define the outputpath.
# 2.  outputpath variable contains the folder name in which model will be saved.

# %%
outputpath = input("Write the outputpath where previous training was done?\n")
clear_output()

obj_file = None
cfg_file = None
last_weight = None
folder_exists = exists(outputpath)
if folder_exists:
    for i in listdir(outputpath):
        if "obj.data" in i:
            obj_file = join(outputpath, i)
        elif ".cfg" in i:
            cfg_file = join(outputpath, i)
        elif "last.weights" in i:
            last_weight = join(outputpath, i)
else:
    print(outputpath, "does not exist please check the name.")

if (obj_file == None) and (folder_exists):
    print(".data file not found in", outputpath)
if (cfg_file ==None) and (folder_exists):
    print(".cfg file not found in", outputpath)
if (last_weight ==None) and (folder_exists):
    print("last.weights file not found in", outputpath)

if (obj_file != None) and (cfg_file != None) and (last_weight != None):
    # !./darknet detector train $obj_file $cfg_file $last_weight -dont_show -map
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  Prepare additional network for mAP calculation...
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 32, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    8 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    9 route  8 2 	                           ->  304 x 304 x 128
#   10 conv     64       1 x 1/ 1    304 x 304 x 128 ->  304 x 304 x  64 1.514 BF
#   11 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#   12 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   13 route  11 		                           ->  152 x 152 x 128
#   14 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   15 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#   16 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 152 x 152 x  64 0.001 BF
#   18 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#   19 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#   20 Shortcut Layer: 17,  wt = 0, wn = 0, outputs: 152 x 152 x  64 0.001 BF
#   21 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#   22 route  21 12 	                           ->  152 x 152 x 128
#   23 conv    128       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x 128 0.757 BF
#   24 conv    256       3 x 3/ 2    152 x 152 x 128 ->   76 x  76 x 256 3.407 BF
#   25 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   26 route  24 		                           ->   76 x  76 x 256
#   27 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   28 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   29 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   31 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   32 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   34 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   35 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   37 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   38 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   40 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   41 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   43 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   44 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   46 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   47 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   49 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   50 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   52 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   53 route  52 25 	                           ->   76 x  76 x 256
#   54 conv    256       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 256 0.757 BF
#   55 conv    512       3 x 3/ 2     76 x  76 x 256 ->   38 x  38 x 512 3.407 BF
#   56 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   57 route  55 		                           ->   38 x  38 x 512
#   58 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   59 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   60 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   62 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   63 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   65 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   66 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   68 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   69 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   71 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   72 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   74 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   75 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   77 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   78 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   80 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   81 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   83 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   84 route  83 56 	                           ->   38 x  38 x 512
#   85 conv    512       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 512 0.757 BF
#   86 conv   1024       3 x 3/ 2     38 x  38 x 512 ->   19 x  19 x1024 3.407 BF
#   87 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   88 route  86 		                           ->   19 x  19 x1024
#   89 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   90 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#   91 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   92 Shortcut Layer: 89,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#   93 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#   94 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   95 Shortcut Layer: 92,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#   96 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#   97 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   98 Shortcut Layer: 95,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#   99 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#  100 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#  102 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#  103 route  102 87 	                           ->   19 x  19 x1024
#  104 conv   1024       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x1024 0.757 BF
#  105 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  106 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  107 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  108 max                5x 5/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.005 BF
#  109 route  107 		                           ->   19 x  19 x 512
#  110 max                9x 9/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.015 BF
#  111 route  107 		                           ->   19 x  19 x 512
#  112 max               13x13/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.031 BF
#  113 route  112 110 108 107 	                   ->   19 x  19 x2048
#  114 conv    512       1 x 1/ 1     19 x  19 x2048 ->   19 x  19 x 512 0.757 BF
#  115 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  116 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  117 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#  118 upsample                 2x    19 x  19 x 256 ->   38 x  38 x 256
#  119 route  85 		                           ->   38 x  38 x 512
#  120 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  121 route  120 118 	                           ->   38 x  38 x 512
#  122 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  123 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  124 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  125 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  126 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  127 conv    128       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 128 0.095 BF
#  128 upsample                 2x    38 x  38 x 128 ->   76 x  76 x 128
#  129 route  54 		                           ->   76 x  76 x 256
#  130 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  131 route  130 128 	                           ->   76 x  76 x 256
#  132 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  133 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  134 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  135 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  136 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  137 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  138 conv     42       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x  42 0.124 BF
#  139 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.20
# nms_kind: greedynms (1), beta = 0.600000
#  140 route  136 		                           ->   76 x  76 x 128
#  141 conv    256       3 x 3/ 2     76 x  76 x 128 ->   38 x  38 x 256 0.852 BF
#  142 route  141 126 	                           ->   38 x  38 x 512
#  143 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  144 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  145 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  146 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  147 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  148 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  149 conv     42       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x  42 0.062 BF
#  150 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.10
# nms_kind: greedynms (1), beta = 0.600000
#  151 route  147 		                           ->   38 x  38 x 256
#  152 conv    512       3 x 3/ 2     38 x  38 x 256 ->   19 x  19 x 512 0.852 BF
#  153 route  152 116 	                           ->   19 x  19 x1024
#  154 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  155 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  156 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  157 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  158 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  159 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  160 conv     42       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x  42 0.031 BF
#  161 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Total BFLOPS 127.356
# avg_outputs = 1048459
#  Allocate additional workspace_size = 52.43 MB
# big_model_yolov4
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 2, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    8 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    9 route  8 2 	                           ->  304 x 304 x 128
#   10 conv     64       1 x 1/ 1    304 x 304 x 128 ->  304 x 304 x  64 1.514 BF
#   11 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#   12 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   13 route  11 		                           ->  152 x 152 x 128
#   14 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   15 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#   16 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 152 x 152 x  64 0.001 BF
#   18 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#   19 conv     64       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x  64 1.703 BF
#   20 Shortcut Layer: 17,  wt = 0, wn = 0, outputs: 152 x 152 x  64 0.001 BF
#   21 conv     64       1 x 1/ 1    152 x 152 x  64 ->  152 x 152 x  64 0.189 BF
#   22 route  21 12 	                           ->  152 x 152 x 128
#   23 conv    128       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x 128 0.757 BF
#   24 conv    256       3 x 3/ 2    152 x 152 x 128 ->   76 x  76 x 256 3.407 BF
#   25 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   26 route  24 		                           ->   76 x  76 x 256
#   27 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   28 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   29 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   31 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   32 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   34 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   35 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   37 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   38 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   40 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   41 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   43 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   44 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   46 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   47 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   49 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   50 conv    128       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 128 1.703 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  76 x  76 x 128 0.001 BF
#   52 conv    128       1 x 1/ 1     76 x  76 x 128 ->   76 x  76 x 128 0.189 BF
#   53 route  52 25 	                           ->   76 x  76 x 256
#   54 conv    256       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 256 0.757 BF
#   55 conv    512       3 x 3/ 2     76 x  76 x 256 ->   38 x  38 x 512 3.407 BF
#   56 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   57 route  55 		                           ->   38 x  38 x 512
#   58 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   59 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   60 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   62 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   63 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   65 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   66 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   68 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   69 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   71 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   72 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   74 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   75 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   77 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   78 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   80 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   81 conv    256       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 256 1.703 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  38 x  38 x 256 0.000 BF
#   83 conv    256       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 256 0.189 BF
#   84 route  83 56 	                           ->   38 x  38 x 512
#   85 conv    512       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 512 0.757 BF
#   86 conv   1024       3 x 3/ 2     38 x  38 x 512 ->   19 x  19 x1024 3.407 BF
#   87 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   88 route  86 		                           ->   19 x  19 x1024
#   89 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   90 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#   91 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   92 Shortcut Layer: 89,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#   93 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#   94 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   95 Shortcut Layer: 92,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#   96 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#   97 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#   98 Shortcut Layer: 95,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#   99 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#  100 conv    512       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x 512 1.703 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  19 x  19 x 512 0.000 BF
#  102 conv    512       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.189 BF
#  103 route  102 87 	                           ->   19 x  19 x1024
#  104 conv   1024       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x1024 0.757 BF
#  105 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  106 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  107 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  108 max                5x 5/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.005 BF
#  109 route  107 		                           ->   19 x  19 x 512
#  110 max                9x 9/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.015 BF
#  111 route  107 		                           ->   19 x  19 x 512
#  112 max               13x13/ 1     19 x  19 x 512 ->   19 x  19 x 512 0.031 BF
#  113 route  112 110 108 107 	                   ->   19 x  19 x2048
#  114 conv    512       1 x 1/ 1     19 x  19 x2048 ->   19 x  19 x 512 0.757 BF
#  115 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  116 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  117 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#  118 upsample                 2x    19 x  19 x 256 ->   38 x  38 x 256
#  119 route  85 		                           ->   38 x  38 x 512
#  120 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  121 route  120 118 	                           ->   38 x  38 x 512
#  122 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  123 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  124 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  125 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  126 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  127 conv    128       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 128 0.095 BF
#  128 upsample                 2x    38 x  38 x 128 ->   76 x  76 x 128
#  129 route  54 		                           ->   76 x  76 x 256
#  130 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  131 route  130 128 	                           ->   76 x  76 x 256
#  132 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  133 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  134 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  135 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  136 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  137 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  138 conv     42       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x  42 0.124 BF
#  139 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.20
# nms_kind: greedynms (1), beta = 0.600000
#  140 route  136 		                           ->   76 x  76 x 128
#  141 conv    256       3 x 3/ 2     76 x  76 x 128 ->   38 x  38 x 256 0.852 BF
#  142 route  141 126 	                           ->   38 x  38 x 512
#  143 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  144 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  145 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  146 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  147 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#  148 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#  149 conv     42       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x  42 0.062 BF
#  150 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.10
# nms_kind: greedynms (1), beta = 0.600000
#  151 route  147 		                           ->   38 x  38 x 256
#  152 conv    512       3 x 3/ 2     38 x  38 x 256 ->   19 x  19 x 512 0.852 BF
#  153 route  152 116 	                           ->   19 x  19 x1024
#  154 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  155 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  156 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  157 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  158 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#  159 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#  160 conv     42       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x  42 0.031 BF
#  161 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Total BFLOPS 127.356
# avg_outputs = 1048459
#  Allocate additional workspace_size = 118.88 MB
# Loading weights from footwear_big_model/big_model_yolov4_last.weights...
#  seen 64, trained: 680 K-images (10 Kilo-batches_64)
# Done! Loaded 162 layers from weights-file
# Learning Rate: 0.001, Momentum: 0.949, Decay: 0.0005
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# Resizing, random_coef = 1.40
#
#  896 x 896
#  Create 6 permanent cpu-threads
#  try to allocate additional workspace_size = 258.14 MB
#  CUDA allocate done!
# Loaded: 26.073609 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.768743), count: 11, class_loss = 6.234937, iou_loss = 78.358009, total_loss = 84.592949
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.730448), count: 24, class_loss = 11.580310, iou_loss = 57.353497, total_loss = 68.933807
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.747403), count: 17, class_loss = 10.268438, iou_loss = 12.269184, total_loss = 22.537622
#  total_bbox = 52, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.804250), count: 1, class_loss = 0.559840, iou_loss = 16.424370, total_loss = 16.984209
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.655327), count: 6, class_loss = 2.330362, iou_loss = 8.660288, total_loss = 10.990649
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.765669), count: 17, class_loss = 5.881961, iou_loss = 5.291396, total_loss = 11.173357
#  total_bbox = 76, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.492886), count: 4, class_loss = 4.398344, iou_loss = 25.468428, total_loss = 29.866772
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.759448), count: 5, class_loss = 4.632953, iou_loss = 12.529138, total_loss = 17.162090
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.840263), count: 12, class_loss = 7.544861, iou_loss = 4.581591, total_loss = 12.126451
#  total_bbox = 97, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000503, iou_loss = 0.000000, total_loss = 0.000503
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.738507), count: 7, class_loss = 3.371488, iou_loss = 8.580148, total_loss = 11.951635
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.765606), count: 14, class_loss = 6.814677, iou_loss = 4.781433, total_loss = 11.596110
#  total_bbox = 118, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.002048, iou_loss = 0.000000, total_loss = 0.002048
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.778407), count: 5, class_loss = 2.304702, iou_loss = 12.559364, total_loss = 14.864066
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.835289), count: 18, class_loss = 7.754083, iou_loss = 4.363360, total_loss = 12.117443
#  total_bbox = 141, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.018168, iou_loss = 0.000000, total_loss = 0.018168
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.760299), count: 9, class_loss = 5.032675, iou_loss = 21.904959, total_loss = 26.937634
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.733006), count: 16, class_loss = 7.331564, iou_loss = 7.331660, total_loss = 14.663224
#  total_bbox = 166, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000009, iou_loss = 0.000000, total_loss = 0.000009
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.787949), count: 5, class_loss = 0.910203, iou_loss = 0.311508, total_loss = 1.221711
#  total_bbox = 171, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000008, iou_loss = 0.000000, total_loss = 0.000008
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.867022), count: 1, class_loss = 0.632391, iou_loss = 1.139058, total_loss = 1.771449
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.788720), count: 8, class_loss = 3.283614, iou_loss = 2.145385, total_loss = 5.428999
#  total_bbox = 180, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000622, iou_loss = 0.000000, total_loss = 0.000622
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.574499), count: 3, class_loss = 3.484341, iou_loss = 0.141899, total_loss = 3.626240
#  total_bbox = 183, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000014, iou_loss = 0.000000, total_loss = 0.000014
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.443874), count: 1, class_loss = 2.138391, iou_loss = 0.346572, total_loss = 2.484964
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.689247), count: 9, class_loss = 5.234804, iou_loss = 1.280530, total_loss = 6.515334
#  total_bbox = 193, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.672424), count: 1, class_loss = 0.423474, iou_loss = 0.666438, total_loss = 1.089912
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.676664), count: 9, class_loss = 4.813529, iou_loss = 1.628808, total_loss = 6.442338
#  total_bbox = 203, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.585371), count: 4, class_loss = 3.239708, iou_loss = 33.403130, total_loss = 36.642838
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.732559), count: 11, class_loss = 6.769144, iou_loss = 16.646448, total_loss = 23.415592
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.811291), count: 21, class_loss = 5.354847, iou_loss = 13.511749, total_loss = 18.866596
#  total_bbox = 239, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.004391, iou_loss = 0.000000, total_loss = 0.004391
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.693350), count: 8, class_loss = 5.630505, iou_loss = 8.476252, total_loss = 14.106756
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.715910), count: 23, class_loss = 14.674106, iou_loss = 4.652705, total_loss = 19.326811
#  total_bbox = 270, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.700026), count: 2, class_loss = 0.896263, iou_loss = 14.525545, total_loss = 15.421807
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.758801), count: 17, class_loss = 8.542730, iou_loss = 35.317612, total_loss = 43.860344
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.756819), count: 15, class_loss = 7.377064, iou_loss = 6.416075, total_loss = 13.793139
#  total_bbox = 304, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.008479, iou_loss = 0.000000, total_loss = 0.008479
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.768208), count: 8, class_loss = 8.181441, iou_loss = 14.888656, total_loss = 23.070097
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.745822), count: 16, class_loss = 11.388854, iou_loss = 5.365134, total_loss = 16.753988
#  total_bbox = 328, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.645155), count: 2, class_loss = 1.285312, iou_loss = 9.830958, total_loss = 11.116270
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.763888), count: 10, class_loss = 6.775851, iou_loss = 32.244572, total_loss = 39.020424
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.804143), count: 6, class_loss = 1.672088, iou_loss = 2.150187, total_loss = 3.822275
#  total_bbox = 346, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.843983), count: 1, class_loss = 0.214416, iou_loss = 8.623904, total_loss = 8.838320
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.790325), count: 7, class_loss = 0.810636, iou_loss = 14.859096, total_loss = 15.669731
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.752984), count: 11, class_loss = 5.315333, iou_loss = 2.369551, total_loss = 7.684885
#  total_bbox = 365, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000575, iou_loss = 0.000000, total_loss = 0.000575
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.774638), count: 12, class_loss = 6.854536, iou_loss = 19.528755, total_loss = 26.383291
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.835816), count: 33, class_loss = 8.458794, iou_loss = 11.372480, total_loss = 19.831274
#  total_bbox = 410, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.017521, iou_loss = 0.000000, total_loss = 0.017521
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.773157), count: 4, class_loss = 2.210373, iou_loss = 4.808870, total_loss = 7.019243
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.791839), count: 20, class_loss = 7.280573, iou_loss = 5.006480, total_loss = 12.287053
#  total_bbox = 434, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000029, iou_loss = 0.000000, total_loss = 0.000029
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.689699), count: 8, class_loss = 5.492657, iou_loss = 10.295094, total_loss = 15.787751
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.765986), count: 15, class_loss = 10.756774, iou_loss = 3.591365, total_loss = 14.348139
#  total_bbox = 457, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.794050), count: 3, class_loss = 1.670325, iou_loss = 16.712452, total_loss = 18.382776
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.812864), count: 16, class_loss = 8.944030, iou_loss = 32.157310, total_loss = 41.101341
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.764756), count: 23, class_loss = 9.885297, iou_loss = 8.909488, total_loss = 18.794785
#  total_bbox = 499, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000064, iou_loss = 0.000000, total_loss = 0.000064
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.558418), count: 3, class_loss = 2.239062, iou_loss = 7.276929, total_loss = 9.515991
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.800570), count: 13, class_loss = 10.910787, iou_loss = 1.866508, total_loss = 12.777295
#  total_bbox = 515, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.715785), count: 5, class_loss = 0.896974, iou_loss = 7.041399, total_loss = 7.938374
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.757709), count: 7, class_loss = 0.499688, iou_loss = 2.163856, total_loss = 2.663544
#  total_bbox = 527, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.822368), count: 1, class_loss = 0.127664, iou_loss = 10.112354, total_loss = 10.240018
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.818020), count: 6, class_loss = 0.035021, iou_loss = 16.576826, total_loss = 16.611847
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.788991), count: 5, class_loss = 1.375307, iou_loss = 1.577375, total_loss = 2.952682
#  total_bbox = 539, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000007, iou_loss = 0.000000, total_loss = 0.000007
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000101, iou_loss = 0.000000, total_loss = 0.000101
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.801544), count: 6, class_loss = 0.504745, iou_loss = 0.671619, total_loss = 1.176364
#  total_bbox = 545, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.496627), count: 2, class_loss = 1.670936, iou_loss = 0.930949, total_loss = 2.601884
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.486187), count: 8, class_loss = 5.286544, iou_loss = 0.801936, total_loss = 6.088480
#  total_bbox = 555, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.008061, iou_loss = 0.000000, total_loss = 0.008061
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.690989), count: 4, class_loss = 2.083895, iou_loss = 6.103595, total_loss = 8.187490
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.802004), count: 5, class_loss = 3.489066, iou_loss = 2.682245, total_loss = 6.171311
#  total_bbox = 564, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.780228), count: 2, class_loss = 0.777071, iou_loss = 6.042967, total_loss = 6.820038
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.753070), count: 8, class_loss = 2.519523, iou_loss = 15.735428, total_loss = 18.254951
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.805087), count: 16, class_loss = 7.251290, iou_loss = 6.987013, total_loss = 14.238303
#  total_bbox = 590, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.862117), count: 2, class_loss = 0.094177, iou_loss = 21.219200, total_loss = 21.313377
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.773789), count: 11, class_loss = 3.828623, iou_loss = 22.468117, total_loss = 26.296740
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.786016), count: 14, class_loss = 7.113600, iou_loss = 6.790295, total_loss = 13.903895
#  total_bbox = 617, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000191, iou_loss = 0.000000, total_loss = 0.000191
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.730170), count: 8, class_loss = 1.124518, iou_loss = 13.688455, total_loss = 14.812973
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.824699), count: 10, class_loss = 2.625623, iou_loss = 3.865335, total_loss = 6.490958
#  total_bbox = 635, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.010665, iou_loss = 0.000000, total_loss = 0.010665
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.683099), count: 6, class_loss = 2.982589, iou_loss = 7.005736, total_loss = 9.988326
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.796310), count: 10, class_loss = 3.184486, iou_loss = 3.261224, total_loss = 6.445709
#  total_bbox = 651, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000438, iou_loss = 0.000000, total_loss = 0.000438
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.774354), count: 5, class_loss = 2.245449, iou_loss = 9.146268, total_loss = 11.391717
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.821943), count: 12, class_loss = 4.678989, iou_loss = 3.026256, total_loss = 7.705245
#  total_bbox = 668, rewritten_bbox = 0.000000 %
#
#
#  Tensor Cores are used.
#  (next mAP calculation at 11042 iterations)
#  10635: 3.384473, 3.384473 avg loss, 0.001000 rate, 21.169216 seconds, 680640 images, -1.000000 hours left
# Loaded: 9.293610 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.012029, iou_loss = 0.000000, total_loss = 0.012029
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.539582), count: 3, class_loss = 3.323642, iou_loss = 2.142617, total_loss = 5.466259
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.666161), count: 6, class_loss = 3.066396, iou_loss = 0.920414, total_loss = 3.986810
#  total_bbox = 677, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000055, iou_loss = 0.000000, total_loss = 0.000055
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000040, iou_loss = 0.000000, total_loss = 0.000040
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.773151), count: 1, class_loss = 0.958680, iou_loss = 0.051571, total_loss = 1.010251
#  total_bbox = 678, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.820454), count: 3, class_loss = 3.053797, iou_loss = 37.203659, total_loss = 40.257454
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.682622), count: 6, class_loss = 2.990557, iou_loss = 13.224236, total_loss = 16.214792
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.781332), count: 6, class_loss = 0.963376, iou_loss = 1.026845, total_loss = 1.990221
#  total_bbox = 693, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000562, iou_loss = 0.000000, total_loss = 0.000562
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.739907), count: 1, class_loss = 0.576541, iou_loss = 0.433105, total_loss = 1.009647
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.752947), count: 6, class_loss = 3.131126, iou_loss = 0.803489, total_loss = 3.934615
#  total_bbox = 700, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000006, iou_loss = 0.000000, total_loss = 0.000006
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000054, iou_loss = 0.000000, total_loss = 0.000054
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.721243), count: 5, class_loss = 3.799237, iou_loss = 0.659093, total_loss = 4.458330
#  total_bbox = 705, rewritten_bbox = 0.000000 %
# ...
#  total_bbox = 3947, rewritten_bbox = 0.076007 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.020606, iou_loss = 0.000000, total_loss = 0.020606
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.837037), count: 7, class_loss = 1.567536, iou_loss = 2.293332, total_loss = 3.860868
#  total_bbox = 3954, rewritten_bbox = 0.075873 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000197, iou_loss = 0.000000, total_loss = 0.000197
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.710412), count: 2, class_loss = 0.881995, iou_loss = 2.908659, total_loss = 3.790654
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.779183), count: 8, class_loss = 2.526958, iou_loss = 1.723732, total_loss = 4.250690
#  total_bbox = 3964, rewritten_bbox = 0.075681 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000414, iou_loss = 0.000000, total_loss = 0.000414
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.824532), count: 4, class_loss = 1.537383, iou_loss = 8.286083, total_loss = 9.823466
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.803183), count: 12, class_loss = 6.322009, iou_loss = 6.255889, total_loss = 12.577898
#  total_bbox = 3980, rewritten_bbox = 0.075377 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.544477), count: 1, class_loss = 0.892187, iou_loss = 14.423737, total_loss = 15.315924
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.837359), count: 7, class_loss = 4.345726, iou_loss = 8.765449, total_loss = 13.111175
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.819147), count: 25, class_loss = 13.665091, iou_loss = 8.181374, total_loss = 21.846464
#  total_bbox = 4013, rewritten_bbox = 0.074757 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000115, iou_loss = 0.000000, total_loss = 0.000115
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.724949), count: 12, class_loss = 6.306450, iou_loss = 16.293476, total_loss = 22.599926
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.805182), count: 33, class_loss = 8.448297, iou_loss = 8.176053, total_loss = 16.624350
#  total_bbox = 4058, rewritten_bbox = 0.073928 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000176, iou_loss = 0.000000, total_loss = 0.000176
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.730875), count: 5, class_loss = 2.042023, iou_loss = 24.834566, total_loss = 26.876589
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.835611), count: 23, class_loss = 5.263523, iou_loss = 4.193170, total_loss = 9.456693
#  total_bbox = 4086, rewritten_bbox = 0.073421 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.606885), count: 1, class_loss = 0.852062, iou_loss = 4.179921, total_loss = 5.031984
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.867989), count: 1, class_loss = 1.045177, iou_loss = 0.749787, total_loss = 1.794964
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.841611), count: 24, class_loss = 9.508938, iou_loss = 6.564835, total_loss = 16.073772
#  total_bbox = 4112, rewritten_bbox = 0.072957 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.005962, iou_loss = 0.000000, total_loss = 0.005962
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.749721), count: 9, class_loss = 1.716698, iou_loss = 14.635164, total_loss = 16.351862
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.815529), count: 14, class_loss = 6.409956, iou_loss = 6.972986, total_loss = 13.382941
#  total_bbox = 4135, rewritten_bbox = 0.072551 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000394, iou_loss = 0.000000, total_loss = 0.000394
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.773162), count: 7, class_loss = 3.195866, iou_loss = 9.794857, total_loss = 12.990724
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.840500), count: 27, class_loss = 7.419497, iou_loss = 8.482938, total_loss = 15.902435
#  total_bbox = 4169, rewritten_bbox = 0.071960 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000335, iou_loss = 0.000000, total_loss = 0.000335
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.747017), count: 18, class_loss = 9.730342, iou_loss = 31.926491, total_loss = 41.656834
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.795699), count: 27, class_loss = 9.486842, iou_loss = 10.261128, total_loss = 19.747971
#  total_bbox = 4214, rewritten_bbox = 0.071191 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.784003), count: 4, class_loss = 2.729925, iou_loss = 40.211655, total_loss = 42.941582
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.695203), count: 9, class_loss = 5.301849, iou_loss = 18.702688, total_loss = 24.004538
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.831321), count: 23, class_loss = 5.196916, iou_loss = 5.788854, total_loss = 10.985769
#  total_bbox = 4250, rewritten_bbox = 0.070588 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000291, iou_loss = 0.000000, total_loss = 0.000291
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.790044), count: 2, class_loss = 1.319056, iou_loss = 1.484403, total_loss = 2.803459
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.838546), count: 23, class_loss = 13.329917, iou_loss = 5.492930, total_loss = 18.822847
#  total_bbox = 4275, rewritten_bbox = 0.070175 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.799758), count: 7, class_loss = 1.339615, iou_loss = 0.840581, total_loss = 2.180196
#  total_bbox = 4282, rewritten_bbox = 0.070061 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.774199, iou_loss = 0.000000, total_loss = 0.774199
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.734683), count: 10, class_loss = 1.079415, iou_loss = 1.587018, total_loss = 2.666433
#  total_bbox = 4292, rewritten_bbox = 0.069897 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000144, iou_loss = 0.000000, total_loss = 0.000144
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.854423), count: 6, class_loss = 1.521273, iou_loss = 0.747643, total_loss = 2.268916
#  total_bbox = 4298, rewritten_bbox = 0.069800 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000012, iou_loss = 0.000000, total_loss = 0.000012
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.775343), count: 2, class_loss = 1.484572, iou_loss = 1.329517, total_loss = 2.814090
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.813566), count: 8, class_loss = 2.212503, iou_loss = 2.658924, total_loss = 4.871427
#  total_bbox = 4308, rewritten_bbox = 0.069638 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.781574), count: 5, class_loss = 2.025207, iou_loss = 6.272928, total_loss = 8.298136
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.741961), count: 8, class_loss = 1.653520, iou_loss = 2.194354, total_loss = 3.847874
#  total_bbox = 4321, rewritten_bbox = 0.069428 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000046, iou_loss = 0.000000, total_loss = 0.000046
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000152, iou_loss = 0.000000, total_loss = 0.000152
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.820637), count: 9, class_loss = 1.915507, iou_loss = 1.552978, total_loss = 3.468485
#  total_bbox = 4330, rewritten_bbox = 0.069284 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000006, iou_loss = 0.000000, total_loss = 0.000006
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.752848), count: 1, class_loss = 0.173577, iou_loss = 1.069429, total_loss = 1.243006
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.889544), count: 10, class_loss = 2.312500, iou_loss = 3.030556, total_loss = 5.343056
#  total_bbox = 4341, rewritten_bbox = 0.069109 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.774868), count: 4, class_loss = 1.318067, iou_loss = 0.345075, total_loss = 1.663142
#  total_bbox = 4345, rewritten_bbox = 0.069045 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000004, iou_loss = 0.000000, total_loss = 0.000004
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.772547), count: 7, class_loss = 2.236145, iou_loss = 0.773468, total_loss = 3.009613
#  total_bbox = 4352, rewritten_bbox = 0.068934 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000548, iou_loss = 0.000000, total_loss = 0.000548
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.727086), count: 6, class_loss = 1.340005, iou_loss = 11.899205, total_loss = 13.239210
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.778618), count: 5, class_loss = 1.893768, iou_loss = 0.966916, total_loss = 2.860684
#  total_bbox = 4363, rewritten_bbox = 0.068760 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.018149, iou_loss = 0.000000, total_loss = 0.018149
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.636270), count: 3, class_loss = 1.514853, iou_loss = 5.104432, total_loss = 6.619286
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.703692), count: 5, class_loss = 1.017555, iou_loss = 0.755628, total_loss = 1.773183
#  total_bbox = 4371, rewritten_bbox = 0.068634 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.817967), count: 3, class_loss = 0.399620, iou_loss = 24.952192, total_loss = 25.351812
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.841214), count: 11, class_loss = 4.194888, iou_loss = 29.369837, total_loss = 33.564724
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.743182), count: 11, class_loss = 6.187131, iou_loss = 2.455981, total_loss = 8.643112
#  total_bbox = 4396, rewritten_bbox = 0.068244 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000111, iou_loss = 0.000000, total_loss = 0.000111
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.892691), count: 4, class_loss = 2.450140, iou_loss = 13.521644, total_loss = 15.971784
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.805161), count: 18, class_loss = 5.066285, iou_loss = 4.468410, total_loss = 9.534696
#  total_bbox = 4418, rewritten_bbox = 0.067904 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000108, iou_loss = 0.000000, total_loss = 0.000108
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.877532), count: 9, class_loss = 2.401843, iou_loss = 23.708986, total_loss = 26.110830
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.821538), count: 23, class_loss = 16.159924, iou_loss = 9.386532, total_loss = 25.546455
#  total_bbox = 4450, rewritten_bbox = 0.067416 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.327796), count: 1, class_loss = 0.708818, iou_loss = 0.825641, total_loss = 1.534459
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.823191), count: 11, class_loss = 3.872570, iou_loss = 14.298532, total_loss = 18.171103
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.737579), count: 18, class_loss = 8.951647, iou_loss = 4.867020, total_loss = 13.818666
#  total_bbox = 4480, rewritten_bbox = 0.066964 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.595750), count: 2, class_loss = 1.082065, iou_loss = 13.850301, total_loss = 14.932365
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.693166), count: 10, class_loss = 5.887560, iou_loss = 23.967402, total_loss = 29.854961
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.806171), count: 23, class_loss = 9.006410, iou_loss = 8.146987, total_loss = 17.153397
#  total_bbox = 4515, rewritten_bbox = 0.066445 %
#
#
#  Tensor Cores are used.
#  (next mAP calculation at 11042 iterations)
#  10642: 2.462145, 2.835054 avg loss, 0.001000 rate, 23.430914 seconds, 681088 images, 94.636204 hours left
# ^C
