# %% [markdown]
# <a href="https://colab.research.google.com/github/khatana706/DATA-SCIENCE/blob/main/image_pre_procesiing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

# %%
# !pip install pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install pytesseract
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pytesseract
import cv2
from PIL import Image
# %matplotlib inline

# %%
from pylab import *

# %%
import pylab
import PIL

# %%
my_img = cv2.imread("/content/leubolin.jpg")

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(my_img)
# Out:
# <PIL.Image.Image image mode=RGB size=230x153>

# %%
pylab.imshow(my_img)

# %%
my_img.shape
# Out:
# (153, 230, 3)

# %%
import  cv2
import numpy as np
from skimage.util import random_noise

# %%
#Load the image
img = cv2.imread("/content/leubolin.jpg")

# %%
 from google.colab.patches import cv2_imshow

# %%
#add salt-and papper noise to the image 
noise_img_salt = random_noise(img, mode='s&p', amount=0.3)
noise_img_salt = np.array(255*noise_img_salt, dtype='uint8')
cv2_imshow(noise_img_salt)
# Out:
# <PIL.Image.Image image mode=RGB size=230x153>

# %%
#add salt-and papper noise to the image 
#noise_img_salt = random_noise(img, mode='s&p', amount=0.5)
#noise_img_salt = np.array(255*noise_img_salt, dtype='uint8')
#cv2_imshow(noise_img_salt)

# %%
#add noise using Gaussian filtter

# %%
img.shape
# Out:
# (153, 230, 3)

# %%
noise_Gaussian_img = random_noise(img, mode='gaussian')
noise_Gaussian_img = np.array(255*noise_Gaussian_img, dtype='uint8')
cv2_imshow(noise_Gaussian_img)
# Out:
# <PIL.Image.Image image mode=RGB size=230x153>

# %%
noise_Gaussian_img.shape
# Out:
# (153, 230, 3)

# %%
#implement of non local means algorithm (NLM)
"""the non-local_means algorithm replace the value of a pixel by an avreage
 of a selection of other pixel valkues small patches centered an the other 
 avreage is performed only for pixel that have patches close to the patch"""
# Out:
# 'the non-local_means algorithm replace the value of a pixel by an avreage\n of a selection of other pixel valkues small patches centered an the other \n avreage is performed only for pixel that have patches close to the patch'

# %%
import numpy as np
import cv2
from skimage import io, img_as_float
from skimage.restoration import denoise_nl_means, estimate_sigma

img = img_as_float(io.imread('/content/leubolin.jpg', as_gray=False))

sigma_est = np.mean(estimate_sigma(img, multichannel=True))
denoise_img = denoise_nl_means(img, h=1*sigma_est, fast_mode=True, patch_size=5, patch_distance=3, multichannel=True)

# %%
"""
when the fast_mode argument is false a spatial Gaussian weighting is applied to 
the patch distance. when fast_mode is True a 
faster algorithm employing uniform spatial weightingh on the patches is applied.

Larger h allows more smoothing between disimilar patches.

"""
# Out:
# '\nwhen the fast_mode argument is false a spatial Gaussian weighting is applied to \nthe patch distance. when fast_mode is True a \nfaster algorithm employing uniform spatial weightingh on the patches is applied.\n\nLarger h allows more smoothing between disimilar patches.\n\n'

# %%
from skimage import img_as_ubyte
img_as_8byte = img_as_ubyte(img)
denoise_img_as_8byte = img_as_ubyte(denoise_img)
original_img = cv2.cvtColor(img_as_8byte, cv2.COLOR_BGR2RGB)
final_denoise_img = cv2.cvtColor(denoise_img_as_8byte, cv2.COLOR_BGR2RGB)

# %%
cv2_imshow(original_img)
cv2_imshow(final_denoise_img)
# Out:
# <PIL.Image.Image image mode=RGB size=230x153>
# <PIL.Image.Image image mode=RGB size=230x153>

# %%
#implement the wiener filtter

# %%
import skimage
from skimage.viewer import ImageViewer
from skimage import color, data, restoration
import sys
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Viewer requires Qt

# %%
# !sudo apt-get install python3-pyqt5
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   libqt5designer5 libqt5help5 python3-sip
# Suggested packages:
#   python3-pyqt5-dbg
# The following NEW packages will be installed:
#   libqt5designer5 libqt5help5 python3-pyqt5 python3-sip
# 0 upgraded, 4 newly installed, 0 to remove and 62 not upgraded.
# Need to get 5,237 kB of archives.
# After this operation, 22.2 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5designer5 amd64 5.9.5-0ubuntu1 [2,761 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt5help5 amd64 5.9.5-0ubuntu1 [133 kB]
# ...

# %%
# !pip install PyQtWebEngine
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 230 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 67.5 MB 79 kB/s
# ...
#      |████████████████████████████████| 8.4 MB 39.8 MB/s
# ...
#      |████████████████████████████████| 344 kB 44.3 MB/s
# ...
#      |████████████████████████████████| 59.9 MB 98 kB/s
# ...

# %%
# !pip uninstall pyqt5
# Out:
# Found existing installation: PyQt5 5.15.7
# Uninstalling PyQt5-5.15.7:
#   Would remove:
#     /usr/local/bin/pylupdate5
#     /usr/local/bin/pyrcc5
#     /usr/local/bin/pyuic5
#     /usr/local/lib/python3.7/dist-packages/PyQt5-5.15.7.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/PyQt5/*
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.7/dist-packages/PyQt5/Qt5/lib/libQt5Bluetooth.so.5
#     /usr/local/lib/python3.7/dist-packages/PyQt5/Qt5/lib/libQt5Concurrent.so.5
#     /usr/local/lib/python3.7/dist-packages/PyQt5/Qt5/lib/libQt5Core.so.5
#     /usr/local/lib/python3.7/dist-packages/PyQt5/Qt5/lib/libQt5DBus.so.5
#     /usr/local/lib/python3.7/dist-packages/PyQt5/Qt5/lib/libQt5Designer.so.5
#     /usr/local/lib/python3.7/dist-packages/PyQt5/Qt5/lib/libQt5Gui.so.5
#     /usr/local/lib/python3.7/dist-packages/PyQt5/Qt5/lib/libQt5Help.so.5
#     /usr/local/lib/python3.7/dist-packages/PyQt5/Qt5/lib/libQt5Location.so.5
# ...

# %%
#from PyQt5 import QtCore, QtGui, QtWidgets

# %%
#dir(QtGui_cls)

# %%
#dir(QtWidgets)

# %%
#from skimage.viewer.qt import QtGui_cls
#dir(QtGui_cls)
import sys

# %%
import cv2
#Load the image
img = cv2.imread("/content/leubolin.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=230x153>

# %%
 bun = color.rgb2gray(img)
from scipy.signal import convolve2d
psf = np.ones((10, 10)) / 100
bun = convolve2d(bun, psf, 'same')
bun += 0.1 * bun.std() * np.random.standard_normal(bun.shape)

# %%
deconvolved, _ = restoration.unsupervised_wiener(bun, psf)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(8, 5),
                       sharex=True, sharey=True)

plt.gray()

ax[0].imshow(bun, vmin=deconvolved.min(), vmax=deconvolved.max())
ax[0].axis('off')
ax[0].set_title('Original bun')

ax[1].imshow(deconvolved)
ax[1].axis('off')
ax[1].set_title('Restored bun')

fig.tight_layout()

plt.show()
