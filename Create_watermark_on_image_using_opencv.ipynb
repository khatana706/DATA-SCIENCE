# %% [markdown]
# <a href="https://colab.research.google.com/github/khatana706/DATA-SCIENCE/blob/main/Create_watermark_on_image_using_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np

# %%
img1 = cv2.imread('/content/dog1.jpg')

# %%
img2 = cv2.imread('/content/dog2.jpg')

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.shape
# Out:
# (171, 284, 3)

# %%
img2.shape
# Out:
# (169, 253, 3)

# %%
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img1
# Out:
# array([[[128,  95,  60],
#         [162, 129,  94],
#         [171, 138, 103],
#         ...,
#         [116,  99,  69],
#         [104,  87,  61],
#         [ 98,  81,  55]],
#
#        [[169, 136, 101],
#         [185, 152, 117],
#         [180, 147, 112],
#         ...,
#         [120, 103,  73],
#         [116,  99,  71],
#         [113,  96,  70]],
#
#        [[199, 167, 129],
#         [199, 167, 129],
#         [185, 152, 117],
#         ...,
#         [ 99,  82,  52],
#         [108,  91,  63],
#         [111,  94,  66]],
#
#        ...,
#
#        [[195, 156, 141],
#         [193, 154, 139],
#         [194, 155, 140],
#         ...,
#         [ 59,  49,  57],
#         [ 59,  49,  57],
#         [ 59,  49,  57]],
#
#        [[198, 159, 144],
#         [193, 154, 139],
#         [192, 153, 138],
#         ...,
#         [ 58,  48,  56],
#         [ 58,  48,  56],
#         [ 58,  48,  56]],
#
#        [[202, 163, 148],
#         [194, 155, 140],
#         [190, 151, 136],
# ...

# %%
plt.imshow(img1)

# %%
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img2
# Out:
# array([[[ 17,  36,   4],
#         [  5,  25,   0],
#         [ 23,  43,   8],
#         ...,
#         [ 18,  11,   0],
#         [ 29,  22,   6],
#         [ 31,  25,  11]],
#
#        [[ 45,  64,  32],
#         [ 30,  50,  15],
#         [ 19,  39,   2],
#         ...,
#         [ 37,  30,  14],
#         [ 44,  37,  21],
#         [ 44,  38,  24]],
#
#        [[ 26,  45,  13],
#         [119, 139, 104],
#         [141, 161, 124],
#         ...,
#         [ 51,  44,  26],
#         [ 64,  57,  39],
#         [ 69,  63,  47]],
#
#        ...,
#
#        [[ 80,  48,  23],
#         [ 87,  55,  30],
#         [126,  95,  67],
#         ...,
#         [118,  72,  38],
#         [161, 113,  77],
#         [169, 119,  82]],
#
#        [[106,  74,  49],
#         [ 80,  48,  23],
#         [ 88,  57,  29],
#         ...,
#         [183, 135,  99],
#         [166, 116,  79],
#         [177, 125,  86]],
#
#        [[ 87,  55,  30],
#         [108,  76,  51],
#         [113,  82,  54],
# ...

# %%
plt.imshow(img2)

# %%
img1.shape
# Out:
# (171, 284, 3)

# %%
img2.shape
# Out:
# (169, 253, 3)

# %%
img1 = cv2.resize(img1,(1200,1200))

# %%
img1.shape
# Out:
# (1200, 1200, 3)

# %%
img2 = cv2.resize(img2,(400,400))

# %%
img2.shape
# Out:
# (400, 400, 3)

# %%
plt.imshow(img1)

# %%
img1.shape
# Out:
# (1200, 1200, 3)

# %%
plt.imshow(img2)

# %%
watermark = cv2.addWeighted(src1=img1,alpha=0.9,src2=img2,beta=0.1,gamma=0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-151-79301150c95c> in <module>()
# ----> 1 watermark = cv2.addWeighted(src1=img1,alpha=0.9,src2=img2,beta=0.1,gamma=0)
#
# error: OpenCV(4.1.2) /io/opencv/modules/core/src/arithm.cpp:663: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'arithm_op'
